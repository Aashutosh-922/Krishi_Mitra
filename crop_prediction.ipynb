# %% [markdown]
# <a href="https://colab.research.google.com/github/Aashutosh-922/Krishi_Mitra/blob/main/crop_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/Crop_recommendation.csv')

# %%
df=df.astype('category')

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
categorical_column = df['label']

# %%
encoder = OrdinalEncoder()

# %%
encoded_column = encoder.fit_transform(categorical_column.values.reshape(-1, 1))

# %%
df['Label_grains'] = encoded_column

# %%
print(df)
# Out:
#         N   P   K temperature   humidity        ph    rainfall   label  \
# 0      90  42  43   20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41   21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44   23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40   26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42   20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..         ...        ...       ...         ...     ...
# 2195  107  34  32   26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27   27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30   24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34   26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30   23.603016  60.396475  6.779833  140.937041  coffee
#
#       Label_grains
# 0             20.0
# 1             20.0
# 2             20.0
# 3             20.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in df.columns:
    df[column] = le.fit_transform(df[column])

# %%
x = df.drop('label',axis=1)

# %%
x
# Out:
#         N   P   K  temperature  humidity    ph  rainfall  Label_grains
# 0      90  37  38          361      1234  1211      2074            20
# 1      85  53  36          437      1085  1753      2128            20
# 2      60  50  39          583      1262  2117      2174            20
# 3      74  30  35         1279      1067  1710      2153            20
# 4      78  37  37          307      1201  2055      2171            20
# ...   ...  ..  ..          ...       ...   ...       ...           ...
# 2195  107  29  27         1328       763  1523      1920             5
# 2196   99  10  22         1442       483   666      1666             5
# 2197  118  28  25          789       793  1012      1895             5
# 2198  117  27  29         1237       387  1493      1663             5
# 2199  104  13  25          694       555  1521      1723             5
#
# [2200 rows x 8 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
x = df.drop('Label_grains',axis=1)
y = df['Label_grains']

# %%
df.isnull()
# Out:
#           N      P      K  temperature  humidity     ph  rainfall  label  \
# 0     False  False  False        False     False  False     False  False
# 1     False  False  False        False     False  False     False  False
# 2     False  False  False        False     False  False     False  False
# 3     False  False  False        False     False  False     False  False
# 4     False  False  False        False     False  False     False  False
# ...     ...    ...    ...          ...       ...    ...       ...    ...
# 2195  False  False  False        False     False  False     False  False
# 2196  False  False  False        False     False  False     False  False
# 2197  False  False  False        False     False  False     False  False
# 2198  False  False  False        False     False  False     False  False
# 2199  False  False  False        False     False  False     False  False
#
#       Label_grains
# 0            False
# 1            False
# 2            False
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rm = RandomForestClassifier()
rm.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.svm import SVC
svc = SVC()
clf=svc.fit(X_train,y_train)

# %%
y_pred1 = svc.predict(X_test)

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
y_pred = rm.predict(X_test)

# %%
y_pred
# Out:
# array([15, 21, 17, 17,  0, 12,  0, 13, 14, 10,  2,  4, 19,  8,  4, 19,  0,
#        11, 17, 15,  5, 17, 16, 17,  3,  8, 14, 16, 18, 20, 19, 13,  8, 10,
#         8,  2,  8,  3,  3,  9, 17, 12,  2, 11, 14, 11, 18,  4, 15, 11,  2,
#         5,  7, 14,  5,  9,  6,  0,  1,  2, 21,  4, 10, 16, 17, 18, 16, 20,
#        15, 18, 15,  4,  8,  1,  2, 17,  1,  6, 21, 16,  5,  3, 20, 13, 16,
#        12,  5, 13,  2, 19, 11, 13,  6, 17, 18, 13,  9,  5,  2, 10,  4, 20,
#        16, 15, 21,  9, 21,  1, 18, 13,  1,  8,  6, 19, 18,  3, 11,  4, 19,
#        20, 18,  7,  2,  4,  3,  2,  4, 11,  1, 13,  1,  9, 19,  3,  4, 16,
#        18,  1,  1,  0,  9, 15, 14, 13,  4, 11,  0,  4,  9, 13, 14, 10, 21,
#        14, 18, 18, 18,  9, 11,  8,  3,  0, 16,  6, 20,  4,  7, 10, 21,  7,
#         7,  2, 19,  3,  4, 11, 10,  7, 21,  8,  5,  5,  9,  8, 13,  9,  1,
#         9,  4, 17, 17, 14, 12, 19, 21,  9, 11,  0,  2,  3,  7,  7,  1,  6,
# ...

# %%
from sklearn.metrics import accuracy_score
print("RM",accuracy_score(y_test,y_pred))
print("SVC",accuracy_score(y_test,y_pred1))
# Out:
# RM 1.0
# SVC 0.8477272727272728
